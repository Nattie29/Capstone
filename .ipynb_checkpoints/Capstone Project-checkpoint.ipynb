# %% [markdown]
# # Capstone Project AQI to the Death
# #### Nattawaree Piyarat
#
# Import necessary libraries.
#
# Load dataset and perform data wrangling.

# %%
import numpy as np
import pandas as pd

# plotting
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.graph_objs as go
import matplotlib.pyplot as plt
import seaborn as sns

## TODO - DTALE - DATA Visulization library

# stats
from statsmodels.api import tsa # time series analysis
import statsmodels.api as sm
from scipy import stats
from scipy.stats import norm #used for plotting

# %%
df = pd.read_csv('Research Dataset/who_ambient_air_quality.csv')

# %%
df.head()
# Out:
#   who_region iso3 country_name       city  year                     version  \
# 0     3_Sear  IND        India    Chennai  2018                version 2022
# 1     3_Sear  IND        India    Solapur  2016  version 2022, version 2018
# 2     3_Sear  IND        India    Chennai  2019                version 2022
# 3     3_Sear  IND        India  Hyderabad  2019                version 2022
# 4     3_Sear  IND        India       Pune  2017                version 2022
#
#    pm10_concentration  pm25_concentration  no2_concentration  pm10_tempcov  \
# 0                 NaN                30.0                NaN           NaN
# 1                 NaN                39.0                NaN           NaN
# 2                 NaN                39.0                NaN           NaN
# 3                 NaN                42.0                NaN           NaN
# 4                 NaN                43.0                NaN           NaN
#
#    pm25_tempcov  no2_tempcov type_of_stations  \
# 0          91.0          NaN              NaN
# 1          99.0          NaN              NaN
# 2          85.0          NaN              NaN
# 3          87.0          NaN              NaN
# 4           NaN          NaN              NaN
#
#                                            reference  \
# 0  U.S. Department of State, United States Enviro...
# 1  Central Pollution Control Board India, Environ...
# 2  U.S. Department of State, United States Enviro...
# 3  U.S. Department of State, United States Enviro...
# 4  Central Pollution Control Board India, Environ...
#
#                                             web_link  population  \
# 0  https://www.airnow.gov/index.cfm?action=airnow...   9890427.0
# 1                                                NaN    985568.0
# 2  [[["EPA AirNow DOS","http://airnow.gov/index.c...   9890427.0
# 3  [[["EPA AirNow DOS","http://airnow.gov/index.c...   8943523.0
# 4                      http://www.cpcb.gov.in/CAAQM/   5727530.0
#
#    population_source   latitude  longitude  who_ms
# 0                NaN  13.087840  80.278470       1
# 1                NaN  17.659919  75.906391       1
# 2                NaN  13.087840  80.278470       1
# 3                NaN  17.384050  78.456360       1
# 4                NaN  18.505320  73.823839       1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 41364 entries, 2018 to 2010
# Data columns (total 20 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   who_region          41364 non-null  object
#  1   iso3                41364 non-null  object
#  2   country_name        41364 non-null  object
#  3   city                41252 non-null  object
#  4   year                41364 non-null  int64
#  5   version             41219 non-null  object
#  6   pm10_concentration  28177 non-null  float64
#  7   pm25_concentration  21566 non-null  float64
#  8   no2_concentration   26704 non-null  float64
#  9   pm10_tempcov        21344 non-null  float64
#  10  pm25_tempcov        16114 non-null  float64
#  11  no2_tempcov         22991 non-null  float64
#  12  type_of_stations    29459 non-null  object
#  13  reference           40538 non-null  object
#  14  web_link            31983 non-null  object
#  15  population          17161 non-null  float64
#  16  population_source   0 non-null      float64
#  17  latitude            41115 non-null  float64
#  18  longitude           41112 non-null  float64
#  19  who_ms              41364 non-null  int64
# dtypes: float64(10), int64(2), object(8)
# memory usage: 6.6+ MB

# %%
# check null value percentage
df.isna().mean()*100
# Out:
# who_region              0.000000
# iso3                    0.000000
# country_name            0.000000
# city                    0.270767
# year                    0.000000
# version                 0.350546
# pm10_concentration     31.880379
# pm25_concentration     47.862876
# no2_concentration      35.441447
# pm10_tempcov           48.399575
# pm25_tempcov           61.043419
# no2_tempcov            44.417851
# type_of_stations       28.781066
# reference               1.996906
# web_link               22.679141
# population             58.512233
# population_source     100.000000
# latitude                0.601973
# longitude               0.609225
# who_ms                  0.000000
# dtype: float64

# %%
df.groupby(df.year)['pm25_concentration'].sum().plot(kind='line',label='PM2.5')
df.groupby(df.year)['pm10_concentration'].sum().plot(kind='line', label='PM10')
plt.legend(loc="upper left")
plt.show()

# %% [markdown]
# Since there are no data of PM10 and PM2.5 before year 2009. So those data should remove.

# %%
 # Delete all rows with column 'year' < 2009
df.drop(df[df.year < 2009].index, inplace=True)
df.head()
# Out:
#   who_region iso3 country_name       city  year                     version  \
# 0     3_Sear  IND        India    Chennai  2018                version 2022
# 1     3_Sear  IND        India    Solapur  2016  version 2022, version 2018
# 2     3_Sear  IND        India    Chennai  2019                version 2022
# 3     3_Sear  IND        India  Hyderabad  2019                version 2022
# 4     3_Sear  IND        India       Pune  2017                version 2022
#
#    pm10_concentration  pm25_concentration  no2_concentration  pm10_tempcov  \
# 0                 NaN                30.0                NaN           NaN
# 1                 NaN                39.0                NaN           NaN
# 2                 NaN                39.0                NaN           NaN
# 3                 NaN                42.0                NaN           NaN
# 4                 NaN                43.0                NaN           NaN
#
#    pm25_tempcov  no2_tempcov type_of_stations  \
# 0          91.0          NaN              NaN
# 1          99.0          NaN              NaN
# 2          85.0          NaN              NaN
# 3          87.0          NaN              NaN
# 4           NaN          NaN              NaN
#
#                                            reference  \
# 0  U.S. Department of State, United States Enviro...
# 1  Central Pollution Control Board India, Environ...
# 2  U.S. Department of State, United States Enviro...
# 3  U.S. Department of State, United States Enviro...
# 4  Central Pollution Control Board India, Environ...
#
#                                             web_link  population  \
# 0  https://www.airnow.gov/index.cfm?action=airnow...   9890427.0
# 1                                                NaN    985568.0
# 2  [[["EPA AirNow DOS","http://airnow.gov/index.c...   9890427.0
# 3  [[["EPA AirNow DOS","http://airnow.gov/index.c...   8943523.0
# 4                      http://www.cpcb.gov.in/CAAQM/   5727530.0
#
#    population_source   latitude  longitude  who_ms
# 0                NaN  13.087840  80.278470       1
# 1                NaN  17.659919  75.906391       1
# 2                NaN  13.087840  80.278470       1
# 3                NaN  17.384050  78.456360       1
# 4                NaN  18.505320  73.823839       1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 41339 entries, 0 to 41363
# Data columns (total 20 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   who_region          41339 non-null  object
#  1   iso3                41339 non-null  object
#  2   country_name        41339 non-null  object
#  3   city                41227 non-null  object
#  4   year                41339 non-null  int64
#  5   version             41194 non-null  object
#  6   pm10_concentration  28152 non-null  float64
#  7   pm25_concentration  21561 non-null  float64
#  8   no2_concentration   26699 non-null  float64
#  9   pm10_tempcov        21339 non-null  float64
#  10  pm25_tempcov        16109 non-null  float64
#  11  no2_tempcov         22986 non-null  float64
#  12  type_of_stations    29434 non-null  object
#  13  reference           40513 non-null  object
#  14  web_link            31958 non-null  object
#  15  population          17136 non-null  float64
#  16  population_source   0 non-null      float64
#  17  latitude            41090 non-null  float64
#  18  longitude           41087 non-null  float64
#  19  who_ms              41339 non-null  int64
# dtypes: float64(10), int64(2), object(8)
# memory usage: 6.6+ MB

# %%
# Drop unnecessory column
df = df.drop(columns=['web_link', 'reference','population_source','pm10_tempcov','pm25_tempcov','no2_tempcov','type_of_stations'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 41339 entries, 0 to 41363
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   who_region          41339 non-null  object
#  1   iso3                41339 non-null  object
#  2   country_name        41339 non-null  object
#  3   city                41227 non-null  object
#  4   year                41339 non-null  int64
#  5   version             41194 non-null  object
#  6   pm10_concentration  28152 non-null  float64
#  7   pm25_concentration  21561 non-null  float64
#  8   no2_concentration   26699 non-null  float64
#  9   population          17136 non-null  float64
#  10  latitude            41090 non-null  float64
#  11  longitude           41087 non-null  float64
#  12  who_ms              41339 non-null  int64
# dtypes: float64(6), int64(2), object(5)
# memory usage: 4.4+ MB

# %%
df.groupby(df.year)['pm25_concentration'].sum().plot(kind='line',label='PM2.5')
df.groupby(df.year)['pm10_concentration'].sum().plot(kind='line', label='PM10')
plt.legend(loc="upper left")
plt.show()

# %%
# Filter only concerned country
country = ["BGD", "BTN", "IDN","IND","LKA","THA"]
df = df[df['iso3'].isin(country)]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1722 entries, 0 to 40445
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   who_region          1722 non-null   object
#  1   iso3                1722 non-null   object
#  2   country_name        1722 non-null   object
#  3   city                1717 non-null   object
#  4   year                1722 non-null   int64
#  5   version             1721 non-null   object
#  6   pm10_concentration  1667 non-null   float64
#  7   pm25_concentration  424 non-null    float64
#  8   no2_concentration   506 non-null    float64
#  9   population          1525 non-null   float64
#  10  latitude            1607 non-null   float64
#  11  longitude           1607 non-null   float64
#  12  who_ms              1722 non-null   int64
# dtypes: float64(6), int64(2), object(5)
# memory usage: 188.3+ KB

# %%
# check null value percentage
df.isna().mean()*100
# Out:
# who_region             0.000000
# iso3                   0.000000
# country_name           0.000000
# city                   0.290360
# year                   0.000000
# version                0.058072
# pm10_concentration     3.193961
# pm25_concentration    75.377468
# no2_concentration     70.615563
# population            11.440186
# latitude               6.678281
# longitude              6.678281
# who_ms                 0.000000
# dtype: float64

# %%
# Lat and Lon should replace by correct data but now will remove, will be correct in next sprint
df.dropna(subset=['latitude'], inplace=True)
# Out:
# C:\Users\Nattawaree\AppData\Local\Temp\ipykernel_26656\1362438331.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(subset=['latitude'], inplace=True)

# %%
# check null value percentage
df.isna().mean()*100
# Out:
# who_region             0.000000
# iso3                   0.000000
# country_name           0.000000
# city                   0.062228
# year                   0.000000
# version                0.062228
# pm10_concentration     3.422526
# pm25_concentration    75.917859
# no2_concentration     75.420037
# population             5.102676
# latitude               0.000000
# longitude              0.000000
# who_ms                 0.000000
# dtype: float64

# %%
# Deathrate dataset has no city, so Air dataset should group by country and set mean data to PM25,PM10,NO2
df.groupby(['year','iso3'])['pm10_concentration'].mean()
# Out:
# year  iso3
# 2010  BGD     173.500000
#       BTN      47.000000
#       IND     176.750000
# 2011  BGD     139.250000
#       BTN      63.250000
#       IDN            NaN
#       IND     108.451429
#       LKA      64.000000
# 2012  BGD     168.000000
#       BTN     105.250000
#       IND     104.836842
# 2013  BGD     129.250000
#       BTN      93.250000
#       IND     100.829694
#       LKA      64.000000
# 2014  BGD     152.222222
#       BTN     109.750000
#       IDN            NaN
#       IND      95.484536
#       THA      44.807692
# 2015  BGD     141.500000
#       BTN     158.500000
#       IDN            NaN
#       IND     101.318841
#       THA      40.000000
# 2016  BGD     128.333333
#       IDN            NaN
#       IND     111.444444
#       THA      43.960000
# 2017  BGD     137.000000
#       IDN      23.500000
#       IND     147.133333
#       LKA            NaN
#       THA      39.900000
# 2018  BGD     146.750000
#       IDN      24.750000
#       IND     113.692308
#       LKA            NaN
# 2019  BGD            NaN
#       IDN      29.000000
#       IND     102.333333
#       LKA            NaN
#       THA      43.516129
# 2020  IDN      16.500000
#       IND      84.590426
# 2021  IDN      19.333333
#       THA      38.510638
# Name: pm10_concentration, dtype: float64

# %%
cols_to_plot = ['iso3','year','pm10_concentration','pm25_concentration','no2_concentration']
sns.pairplot(df[cols_to_plot], hue='iso3')
# Out:
# C:\Users\Nattawaree\Documents\Anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# PM10 and PM25 looks like they have linear relationship

# %% [markdown]
# ### View data of death rate

# %%
df_d = pd.read_csv('Research Dataset/Cause of death/Merge 2016-2019.csv')

# %%
# view data
df_d.head()
# Out:
#    Code                                  Cause     Country iso3  Year   Sex  \
# 0  1140                                 Stroke  Bangladesh  BGD  2016  BTSX
# 1  1130                Ischaemic heart disease  Bangladesh  BGD  2016  BTSX
# 2    30                           Tuberculosis  Bangladesh  BGD  2016  BTSX
# 3   490                    Neonatal conditions  Bangladesh  BGD  2016  BTSX
# 4  1180  Chronic obstructive pulmonary disease  Bangladesh  BGD  2016  BTSX
#
#   Age Group  Population     Deaths  Death rate per 100 000 population  \
# 0   ALLAges   158000000  120674.90                              76.38
# 1   ALLAges   158000000   90632.07                              57.36
# 2   ALLAges   158000000   61224.00                              38.75
# 3   ALLAges   158000000   52495.41                              33.22
# 4   ALLAges   158000000   39330.24                              24.89
#
#         DALY  DALY rate per 100 000 population
# 0  2676519.0                           1694.00
# 1  2216751.0                           1403.01
# 2  2971096.0                           1880.44
# 3  5453862.0                           3451.81
# 4  1037541.0                            656.67

# %%
df_d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3144 entries, 0 to 3143
# Data columns (total 12 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Code                               3144 non-null   int64
#  1   Cause                              3144 non-null   object
#  2   Country                            3144 non-null   object
#  3   ISO3                               3144 non-null   object
#  4   Year                               3144 non-null   int64
#  5   Sex                                3144 non-null   object
#  6   Age Group                          3144 non-null   object
#  7   Population                         3144 non-null   int64
#  8   Deaths                             3144 non-null   float64
#  9   Death rate per 100 000 population  3144 non-null   float64
#  10  DALY                               3144 non-null   float64
#  11  DALY rate per 100 000 population   3144 non-null   float64
# dtypes: float64(4), int64(3), object(5)
# memory usage: 294.9+ KB

# %%
#Check null value
df_d.isna().mean()*100
# Out:
# Code                                 0.0
# Cause                                0.0
# Country                              0.0
# ISO3                                 0.0
# Year                                 0.0
# Sex                                  0.0
# Age Group                            0.0
# Population                           0.0
# Deaths                               0.0
# Death rate per 100 000 population    0.0
# DALY                                 0.0
# DALY rate per 100 000 population     0.0
# dtype: float64

# %%
# Merge to main dataset

result = df.merge(df_d, on='iso3', how='inner')

# %%
result.head()
# Out:
#   who_region iso3 country_name     city  year       version  \
# 0     3_Sear  IND        India  Chennai  2018  version 2022
# 1     3_Sear  IND        India  Chennai  2018  version 2022
# 2     3_Sear  IND        India  Chennai  2018  version 2022
# 3     3_Sear  IND        India  Chennai  2018  version 2022
# 4     3_Sear  IND        India  Chennai  2018  version 2022
#
#    pm10_concentration  pm25_concentration  no2_concentration  population  ...  \
# 0                 NaN                30.0                NaN   9890427.0  ...
# 1                 NaN                30.0                NaN   9890427.0  ...
# 2                 NaN                30.0                NaN   9890427.0  ...
# 3                 NaN                30.0                NaN   9890427.0  ...
# 4                 NaN                30.0                NaN   9890427.0  ...
#
#                                    Cause  Country  Year   Sex Age Group  \
# 0                Ischaemic heart disease    India  2016  BTSX   ALLAges
# 1  Chronic obstructive pulmonary disease    India  2016  BTSX   ALLAges
# 2                    Diarrhoeal diseases    India  2016  BTSX   ALLAges
# 3                                 Stroke    India  2016  BTSX   ALLAges
# 4                    Neonatal conditions    India  2016  BTSX   ALLAges
#
#    Population     Deaths Death rate per 100 000 population        DALY  \
# 0  1320000000  1405038.0                            106.44  36200000.0
# 1  1320000000   821768.5                             62.26  20300000.0
# 2  1320000000   708811.4                             53.70  26200000.0
# 3  1320000000   647625.1                             49.06  16900000.0
# 4  1320000000   501374.3                             37.98  49100000.0
#
#    DALY rate per 100 000 population
# 0                           2742.42
# 1                           1537.88
# 2                           1984.85
# 3                           1280.30
# 4                           3719.70
#
# [5 rows x 24 columns]

# %%
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 842068 entries, 0 to 842067
# Data columns (total 24 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   who_region                         842068 non-null  object
#  1   iso3                               842068 non-null  object
#  2   country_name                       842068 non-null  object
#  3   city                               841544 non-null  object
#  4   year                               842068 non-null  int64
#  5   version                            841544 non-null  object
#  6   pm10_concentration                 813248 non-null  float64
#  7   pm25_concentration                 202788 non-null  float64
#  8   no2_concentration                  206980 non-null  float64
#  9   population                         799100 non-null  float64
#  10  latitude                           842068 non-null  float64
#  11  longitude                          842068 non-null  float64
#  12  who_ms                             842068 non-null  int64
#  13  Code                               842068 non-null  int64
#  14  Cause                              842068 non-null  object
#  15  Country                            842068 non-null  object
#  16  Year                               842068 non-null  int64
#  17  Sex                                842068 non-null  object
#  18  Age Group                          842068 non-null  object
#  19  Population                         842068 non-null  int64
#  20  Deaths                             842068 non-null  float64
#  21  Death rate per 100 000 population  842068 non-null  float64
#  22  DALY                               842068 non-null  float64
#  23  DALY rate per 100 000 population   842068 non-null  float64
# dtypes: float64(10), int64(5), object(9)
# memory usage: 154.2+ MB

# %%
#Check null value
result.isna().mean()*100
# Out:
# who_region                            0.000000
# iso3                                  0.000000
# country_name                          0.000000
# city                                  0.062228
# year                                  0.000000
# version                               0.062228
# pm10_concentration                    3.422526
# pm25_concentration                   75.917859
# no2_concentration                    75.420037
# population                            5.102676
# latitude                              0.000000
# longitude                             0.000000
# who_ms                                0.000000
# Code                                  0.000000
# Cause                                 0.000000
# Country                               0.000000
# Year                                  0.000000
# Sex                                   0.000000
# Age Group                             0.000000
# Population                            0.000000
# Deaths                                0.000000
# Death rate per 100 000 population     0.000000
# DALY                                  0.000000
# DALY rate per 100 000 population      0.000000
# dtype: float64

# %%
df_pm25 = result.loc[result['pm25_concentration'].notnull()]
df_pm10 = result.loc[result['pm10_concentration'].notnull()]
df_no2 = result.loc[result['no2_concentration'].notnull()]
# Data show pm10 or pm25 or no2 so split df to 3 dataframe

# %%
df_pm25.head()
# Out:
#       who_region iso3 country_name      city  year       version  \
# 16244     3_Sear  IND        India  Guwahati  2011  version 2022
# 16245     3_Sear  IND        India  Guwahati  2011  version 2022
# 16246     3_Sear  IND        India  Guwahati  2011  version 2022
# 16247     3_Sear  IND        India  Guwahati  2011  version 2022
# 16248     3_Sear  IND        India  Guwahati  2011  version 2022
#
#        pm10_concentration  pm25_concentration  no2_concentration  population  \
# 16244                 NaN                 NaN               14.0   1042044.0
# 16245                 NaN                 NaN               14.0   1042044.0
# 16246                 NaN                 NaN               14.0   1042044.0
# 16247                 NaN                 NaN               14.0   1042044.0
# 16248                 NaN                 NaN               14.0   1042044.0
#
#        ...                                  Cause  Country  Year   Sex  \
# 16244  ...                Ischaemic heart disease    India  2016  BTSX
# 16245  ...  Chronic obstructive pulmonary disease    India  2016  BTSX
# 16246  ...                    Diarrhoeal diseases    India  2016  BTSX
# 16247  ...                                 Stroke    India  2016  BTSX
# 16248  ...                    Neonatal conditions    India  2016  BTSX
#
#       Age Group  Population     Deaths Death rate per 100 000 population  \
# 16244   ALLAges  1320000000  1405038.0                            106.44
# 16245   ALLAges  1320000000   821768.5                             62.26
# 16246   ALLAges  1320000000   708811.4                             53.70
# 16247   ALLAges  1320000000   647625.1                             49.06
# 16248   ALLAges  1320000000   501374.3                             37.98
#
#              DALY  DALY rate per 100 000 population
# 16244  36200000.0                           2742.42
# 16245  20300000.0                           1537.88
# 16246  26200000.0                           1984.85
# 16247  16900000.0                           1280.30
# 16248  49100000.0                           3719.70
#
# [5 rows x 24 columns]

# %%
df_pm10.head()
# Out:
#       who_region iso3 country_name     city  year       version  \
# 18340     3_Sear  IND        India  Bhiwadi  2017  version 2022
# 18341     3_Sear  IND        India  Bhiwadi  2017  version 2022
# 18342     3_Sear  IND        India  Bhiwadi  2017  version 2022
# 18343     3_Sear  IND        India  Bhiwadi  2017  version 2022
# 18344     3_Sear  IND        India  Bhiwadi  2017  version 2022
#
#        pm10_concentration  pm25_concentration  no2_concentration  population  \
# 18340               391.0               220.0                NaN    104921.0
# 18341               391.0               220.0                NaN    104921.0
# 18342               391.0               220.0                NaN    104921.0
# 18343               391.0               220.0                NaN    104921.0
# 18344               391.0               220.0                NaN    104921.0
#
#        ...                                  Cause  Country  Year   Sex  \
# 18340  ...                Ischaemic heart disease    India  2016  BTSX
# 18341  ...  Chronic obstructive pulmonary disease    India  2016  BTSX
# 18342  ...                    Diarrhoeal diseases    India  2016  BTSX
# 18343  ...                                 Stroke    India  2016  BTSX
# 18344  ...                    Neonatal conditions    India  2016  BTSX
#
#       Age Group  Population     Deaths Death rate per 100 000 population  \
# 18340   ALLAges  1320000000  1405038.0                            106.44
# 18341   ALLAges  1320000000   821768.5                             62.26
# 18342   ALLAges  1320000000   708811.4                             53.70
# 18343   ALLAges  1320000000   647625.1                             49.06
# 18344   ALLAges  1320000000   501374.3                             37.98
#
#              DALY  DALY rate per 100 000 population
# 18340  36200000.0                           2742.42
# 18341  20300000.0                           1537.88
# 18342  26200000.0                           1984.85
# 18343  16900000.0                           1280.30
# 18344  49100000.0                           3719.70
#
# [5 rows x 24 columns]

# %%
df_no2.head()
# Out:
#       who_region iso3 country_name      city  year       version  \
# 16244     3_Sear  IND        India  Guwahati  2011  version 2022
# 16245     3_Sear  IND        India  Guwahati  2011  version 2022
# 16246     3_Sear  IND        India  Guwahati  2011  version 2022
# 16247     3_Sear  IND        India  Guwahati  2011  version 2022
# 16248     3_Sear  IND        India  Guwahati  2011  version 2022
#
#        pm10_concentration  pm25_concentration  no2_concentration  population  \
# 16244                 NaN                 NaN               14.0   1042044.0
# 16245                 NaN                 NaN               14.0   1042044.0
# 16246                 NaN                 NaN               14.0   1042044.0
# 16247                 NaN                 NaN               14.0   1042044.0
# 16248                 NaN                 NaN               14.0   1042044.0
#
#        ...                                  Cause  Country  Year   Sex  \
# 16244  ...                Ischaemic heart disease    India  2016  BTSX
# 16245  ...  Chronic obstructive pulmonary disease    India  2016  BTSX
# 16246  ...                    Diarrhoeal diseases    India  2016  BTSX
# 16247  ...                                 Stroke    India  2016  BTSX
# 16248  ...                    Neonatal conditions    India  2016  BTSX
#
#       Age Group  Population     Deaths Death rate per 100 000 population  \
# 16244   ALLAges  1320000000  1405038.0                            106.44
# 16245   ALLAges  1320000000   821768.5                             62.26
# 16246   ALLAges  1320000000   708811.4                             53.70
# 16247   ALLAges  1320000000   647625.1                             49.06
# 16248   ALLAges  1320000000   501374.3                             37.98
#
#              DALY  DALY rate per 100 000 population
# 16244  36200000.0                           2742.42
# 16245  20300000.0                           1537.88
# 16246  26200000.0                           1984.85
# 16247  16900000.0                           1280.30
# 16248  49100000.0                           3719.70
#
# [5 rows x 24 columns]

# %% [markdown]
# **Hypothesis Test:**
# Null hypothesis is PM2.5 no significant to death rate.
# Alternate hypothesis is PM2.5 significat.
#
# <center> $H_0$: PM2.5 no significant. $\;\; vs \;\;$  $H_1$: PM2.5 significant. </center>

# %%
# There is some issue about merge dataset so in this sprint will not compare PM2.5 and death rate
df_pm25.groupby(['Cause'])['pm25_concentration'].mean()
# Out:
# Cause
# Acute hepatitis A               56.020672
# Acute hepatitis B               56.020672
# Acute hepatitis C               56.020672
# Acute hepatitis E               56.020672
# African trypanosomiasis         56.020672
#                                   ...
# Upper respiratory infections    56.020672
# Urolithiasis                    56.020672
# Vitamin A deficiency            56.020672
# Whooping cough                  56.020672
# Yellow fever                    56.020672
# Name: pm25_concentration, Length: 131, dtype: float64

# %% [markdown]
# **Hypothesis Test:**
# Null hypothesis is PM2.5 no significant to PM10.
# Alternate hypothesis is PM2.5 significant to PM10.
#
# <center> $H_0$: PM2.5 no significant. $\;\; vs \;\;$  $H_1$: PM2.5 significant. </center>

# %%
two_sample_test = stats.ttest_ind(df_pm25['pm25_concentration'], df_pm10['pm10_concentration']) 

print(two_sample_test)

# result shows pvalue 0 due to data does not proper
# Out:
# TtestResult(statistic=-293.79434632264014, pvalue=0.0, df=1016034.0)

# %% [markdown]
# ### Next step
# 1. Update PM10, PM25, NO2 dataset (remove null values)
# 2. Due to data of Deathrate show only country no city so the PM data have to group by country and use mean of PM10,PM25,NO2
# 3. The datapoints too less so add more year especially year which high PM value. And maybe add more countries.
# 4. Modeling and run test for relationship of each independent variables.
